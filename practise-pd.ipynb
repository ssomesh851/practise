# %%
l1 = ['a','b','c']
upper = [x.upper() for x in l1]
upper
# Out:
# ['A', 'B', 'C']

# %%
str = 'abc'
list2 = [x.upper() for x in str]
print(list2)
# Out:
# ['A', 'B', 'C']

# %%
words = ['apple','banana','cherry']
result_l = [x[0] for x in words]
result_l
# Out:
# ['a', 'b', 'c']

# %%
import pandas as pd
url = 'C:\\Users\\lenovo\\Downloads\\abc.csv'
data = pd.read_csv(url, sep=',')
data.head()
# Out:
# E:\anaconda\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         Registrar                     Enrolment Agency          State  \
# 0  Allahabad Bank                A-Onerealtors Pvt Ltd  Uttar Pradesh
# 1  Allahabad Bank         Asha Security Guard Services  Uttar Pradesh
# 2  Allahabad Bank                    SGS INDIA PVT LTD  Uttar Pradesh
# 3  Allahabad Bank  Sri Ramraja Sarkar Lok Kalyan Trust  Uttar Pradesh
# 4  Allahabad Bank                   Transmoovers India  Uttar Pradesh
#
#     District Sub District Pin Code Gender  Age  Aadhaar generated  \
# 0  Allahabad         Meja   212303      F    7                  1
# 1  Sonbhadra  Robertsganj   231213      M    8                  1
# 2  Sultanpur    Sultanpur   227812      F   13                  1
# ...

# %%
data.set_index('State').head(5)
# Out:
#                     Registrar                     Enrolment Agency   District  \
# State
# Uttar Pradesh  Allahabad Bank                A-Onerealtors Pvt Ltd  Allahabad
# Uttar Pradesh  Allahabad Bank         Asha Security Guard Services  Sonbhadra
# Uttar Pradesh  Allahabad Bank                    SGS INDIA PVT LTD  Sultanpur
# Uttar Pradesh  Allahabad Bank  Sri Ramraja Sarkar Lok Kalyan Trust     Shamli
# Uttar Pradesh  Allahabad Bank                   Transmoovers India  Gorakhpur
#
#               Sub District Pin Code Gender  Age  Aadhaar generated  \
# State
# Uttar Pradesh         Meja   212303      F    7                  1
# Uttar Pradesh  Robertsganj   231213      M    8                  1
# Uttar Pradesh    Sultanpur   227812      F   13                  1
# Uttar Pradesh       Shamli   247775      M    6                  1
# Uttar Pradesh     Sahjanwa   273001      M    8                  1
#
#                Enrolment Rejected  Residents providing email  \
# State
# ...

# %%
data.columns = [col.replace(' ','_') for col in data.columns]

# %%
data.columns
# Out:
# Index(['Registrar', 'Enrolment_Agency', 'State', 'District', 'Sub_District',
#        'Pin_Code', 'Gender', 'Age', 'Aadhaar_generated', 'Enrolment_Rejected',
#        'Residents_providing_email', 'Residents_providing_mobile_number'],
#       dtype='object')

# %%
data.columns.str.replace(' ',' _')
# Out:
# Index(['Registrar', 'Enrolment_Agency', 'State', 'District', 'Sub_District',
#        'Pin_Code', 'Gender', 'Age', 'Aadhaar_generated', 'Enrolment_Rejected',
#        'Residents_providing_email', 'Residents_providing_mobile_number'],
#       dtype='object')

# %%
data['location'] = data['State']+' '+data['District']

# %%
data.location.str.replace(', ',' ')
# Out:
# 0          Uttar Pradesh Allahabad
# 1          Uttar Pradesh Sonbhadra
# 2          Uttar Pradesh Sultanpur
# 3             Uttar Pradesh Shamli
# 4          Uttar Pradesh Gorakhpur
# 5           Uttar Pradesh Varanasi
# 6           Uttar Pradesh Varanasi
# 7           Uttar Pradesh Varanasi
# 8           Uttar Pradesh Varanasi
# 9           Uttar Pradesh Varanasi
# 10        Uttar Pradesh Bara Banki
# 11                  Assam Marigaon
# 12                 Bihar Gopalganj
# 13              Karnataka Bagalkot
# 14              Karnataka Bagalkot
# 15              Karnataka Bagalkot
# 16              Karnataka Bagalkot
# 17              Karnataka Bagalkot
# 18              Karnataka Bagalkot
# 19              Karnataka Bagalkot
# 20              Karnataka Bagalkot
# 21              Karnataka Bagalkot
# 22              Karnataka Bagalkot
# 23              Karnataka Bagalkot
# 24              Karnataka Bagalkot
# 25              Karnataka Bagalkot
# 26              Karnataka Bagalkot
# ...

# %%
data.shape[0]
# Out:
# 440818

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440818 entries, 0 to 440817
# Data columns (total 13 columns):
# Registrar                            440818 non-null object
# Enrolment_Agency                     440818 non-null object
# State                                440818 non-null object
# District                             440818 non-null object
# Sub_District                         440818 non-null object
# Pin_Code                             440818 non-null object
# Gender                               440818 non-null object
# Age                                  440818 non-null int64
# Aadhaar_generated                    440818 non-null int64
# Enrolment_Rejected                   440818 non-null int64
# Residents_providing_email            440818 non-null int64
# Residents_providing_mobile_number    440818 non-null int64
# location                             440818 non-null object
# dtypes: int64(5), object(8)
# memory usage: 43.7+ MB

# %%
data.isnull().sum()
# Out:
# Registrar                            0
# Enrolment_Agency                     0
# State                                0
# District                             0
# Sub_District                         0
# Pin_Code                             0
# Gender                               0
# Age                                  0
# Aadhaar_generated                    0
# Enrolment_Rejected                   0
# Residents_providing_email            0
# Residents_providing_mobile_number    0
# location                             0
# dtype: int64

# %%
data.notnull().tail(10)
# Out:
#         Registrar  Enrolment_Agency  State  District  Sub_District  Pin_Code  \
# 440808       True              True   True      True          True      True
# 440809       True              True   True      True          True      True
# 440810       True              True   True      True          True      True
# 440811       True              True   True      True          True      True
# 440812       True              True   True      True          True      True
# 440813       True              True   True      True          True      True
# 440814       True              True   True      True          True      True
# 440815       True              True   True      True          True      True
# 440816       True              True   True      True          True      True
# 440817       True              True   True      True          True      True
#
#         Gender   Age  Aadhaar_generated  Enrolment_Rejected  \
# ...

# %%
#only shows where the column is missing
data[data.State.isnull()]
# Out:
# Empty DataFrame
# Columns: [Registrar, Enrolment_Agency, State, District, Sub_District, Pin_Code, Gender, Age, Aadhaar_generated, Enrolment_Rejected, Residents_providing_email, Residents_providing_mobile_number, location]
# Index: []

# %%
data[data.State.notnull()].head(10)
# Out:
#         Registrar                     Enrolment_Agency          State  \
# 0  Allahabad Bank                A-Onerealtors Pvt Ltd  Uttar Pradesh
# 1  Allahabad Bank         Asha Security Guard Services  Uttar Pradesh
# 2  Allahabad Bank                    SGS INDIA PVT LTD  Uttar Pradesh
# 3  Allahabad Bank  Sri Ramraja Sarkar Lok Kalyan Trust  Uttar Pradesh
# 4  Allahabad Bank                   Transmoovers India  Uttar Pradesh
# 5  Allahabad Bank                   Transmoovers India  Uttar Pradesh
# 6  Allahabad Bank                   Transmoovers India  Uttar Pradesh
# 7  Allahabad Bank                   Transmoovers India  Uttar Pradesh
# 8  Allahabad Bank                   Transmoovers India  Uttar Pradesh
# 9  Allahabad Bank                   Transmoovers India  Uttar Pradesh
#
#     District Sub_District Pin_Code Gender  Age  Aadhaar_generated  \
# 0  Allahabad         Meja   212303      F    7                  1
# ...

# %%
data.sum()

# %%
data.sum(axis=1)

# %%
data.sum(axis=1)

# %%
data.describe()

# %%
data['State'].value_counts().head()

# %%
data[data.State == 'uttar pradesh'].varanasi.value_counts().head(1)

# %%
data[(data.State=='Andhra pradesh') & (data.State=='uttar pradesh')]

# %%
#how many rows are remain if you drop all rows with any missing values?
data.dropna().shape[0]

# %%
#replace any spaces in the columns names with the underscore
data.rename(columns ={'uttar pradesh':'uttar_pradesh', 'Andhra pradesh':'Andhra_pradesh'})

# %%
#for each state calculate the male
data.groupby('State').gender['M'].sum()
